# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
import solar_loader as sl

# %%
# load solar data
SOLAR_TILT = 30 # degrees
DC_SYSTEM_SIZE = 20 # kW
solarData = sl.SolarData(SOLAR_TILT, DC_SYSTEM_SIZE)
gen = solarData.get_full_data()

# %%
# load a carbon trace
cf = pd.read_csv('CISO_direct_emissions.csv', parse_dates=True)
cf['datetime'] = pd.to_datetime(cf['UTC time'], utc=True)
cf.drop(["Unnamed: 0", "UTC time"], axis=1, inplace=True)
cf.set_index('datetime', inplace=True)

# %%
display(gen)
# Out:
#                      DHI  DNI  Dew Point  Surface Albedo  Wind Speed  \
# datetime
# 2019-01-01 00:00:00    0    0       -6.0            0.14         4.0
# 2019-01-01 01:00:00    0    0       -6.0            0.14         3.9
# 2019-01-01 02:00:00    0    0       -6.2            0.14         4.2
# 2019-01-01 03:00:00    0    0       -6.9            0.14         4.4
# 2019-01-01 04:00:00    0    0       -7.0            0.14         4.3
# ...                  ...  ...        ...             ...         ...
# 2021-12-31 19:00:00    0    0        2.5            0.13         2.9
# 2021-12-31 20:00:00    0    0        2.4            0.13         3.6
# 2021-12-31 21:00:00    0    0        2.1            0.13         3.9
# 2021-12-31 22:00:00    0    0        1.5            0.13         4.0
# 2021-12-31 23:00:00    0    0        0.5            0.13         3.9
#
#                      Relative Humidity  Temperature  Pressure  GHI  \
# datetime
# 2019-01-01 00:00:00              49.72          3.5       972    0
# 2019-01-01 01:00:00              51.16          3.1       973    0
# 2019-01-01 02:00:00              50.79          3.0       973    0
# 2019-01-01 03:00:00              48.52          2.9       973    0
# 2019-01-01 04:00:00              48.74          2.7       974    0
# ...                                ...          ...       ...  ...
# 2021-12-31 19:00:00              62.78          9.2       969    0
# 2021-12-31 20:00:00              64.60          8.7       969    0
# 2021-12-31 21:00:00              65.10          8.3       969    0
# 2021-12-31 22:00:00              64.02          7.9       969    0
# 2021-12-31 23:00:00              60.14          7.7       969    0
#
#                      Solar Zenith Angle  Solar Elevation Angle  GTI  \
# datetime
# 2019-01-01 00:00:00              166.60                 -76.60  0.0
# 2019-01-01 01:00:00              156.62                 -66.62  0.0
# 2019-01-01 02:00:00              144.63                 -54.63  0.0
# 2019-01-01 03:00:00              132.25                 -42.25  0.0
# 2019-01-01 04:00:00              119.90                 -29.90  0.0
# ...                                 ...                    ...  ...
# 2021-12-31 19:00:00              121.52                 -31.52  0.0
# 2021-12-31 20:00:00              133.88                 -43.88  0.0
# 2021-12-31 21:00:00              146.24                 -56.24  0.0
# 2021-12-31 22:00:00              158.10                 -68.10  0.0
# 2021-12-31 23:00:00              167.43                 -77.43  0.0
#
#                      Solar Generation (kWh)
# datetime
# 2019-01-01 00:00:00                     0.0
# 2019-01-01 01:00:00                     0.0
# 2019-01-01 02:00:00                     0.0
# 2019-01-01 03:00:00                     0.0
# 2019-01-01 04:00:00                     0.0
# ...                                     ...
# 2021-12-31 19:00:00                     0.0
# 2021-12-31 20:00:00                     0.0
# 2021-12-31 21:00:00                     0.0
# 2021-12-31 22:00:00                     0.0
# 2021-12-31 23:00:00                     0.0
#
# [26280 rows x 13 columns]

# %%
# for each hour, plot a bar graph, where the top half is the percentage of energy not met by solar, and the bottom half is the percentage of energy met by solar
# the color of the top half is based on the carbon intensity
# the color of the bottom half is yellow
import matplotlib

# just 2019 values
cf19 = cf[cf.index.year == 2019]
solar19 = gen[gen.index.year == 2019]

# raw carbon values
carbon = np.array(cf19['carbon_intensity'].to_list())

my_cmap = plt.get_cmap("coolwarm")
rescale = lambda y: (y - np.min(y)) / (np.max(y) - np.min(y))

normalized = [100 for _ in carbon]

# raw solar values
solar = np.array(solar19['Solar Generation (kWh)'].to_list())
# normalized for a 19kW load
solarGen = (solar / 19) * 100

plt.figure(figsize=(18,4), dpi=200)
plt.bar(cf19.index, normalized, color=my_cmap(rescale(carbon)), label="grid electricity")
plt.bar(cf19.index, solarGen, color='yellow', label="solar availability (%)", alpha=0.1)
plt.ylim(0, 100)
plt.xlim(cf19.index[0], cf19.index[-1])

norm = matplotlib.colors.Normalize(vmin=min(carbon),vmax=max(carbon))
sm = plt.cm.ScalarMappable(cmap=plt.get_cmap("coolwarm"), norm=norm)
sm.set_array([])
plt.colorbar(sm, ticks=np.arange(np.floor(min(carbon)), np.ceil(max(carbon)), 20), boundaries=np.arange(min(carbon)-10,max(carbon)+10,1))
plt.tight_layout()
# put the legend at the bottom with two columns
plt.legend(loc='lower center', ncol=2, bbox_to_anchor=(0.5, -0.1))
plt.ylabel("solar availability (%)")
plt.title("2019 CAISO Carbon Intensity vs. Solar Offsets from 20kW DC system (continuous 19kW load)")

plt.show()

# %%
# for each hour, plot a bar graph, where the top half is the percentage of energy not met by solar, and the bottom half is the percentage of energy met by solar
# the color of the top half is based on the carbon intensity
# the color of the bottom half is yellow
import matplotlib

# just 2020 values
solar20 = gen.loc['2020-01-01':'2020-12-31']
cf20 = cf.loc['2020-01-01':'2020-12-31']

# raw carbon values
carbon = np.array(cf20['carbon_intensity'].to_list())

my_cmap = plt.get_cmap("coolwarm")
rescale = lambda y: (y - np.min(y)) / (np.max(y) - np.min(y))

normalized = [100 for _ in carbon]

# raw solar values
solar = np.array(solar20['Solar Generation (kWh)'].to_list())
# normalized for a 19kW load
solarGen = (solar / 19) * 100

plt.figure(figsize=(18,4), dpi=200)
plt.bar(solar20.index, normalized, color=my_cmap(rescale(carbon)), label="grid electricity")
plt.bar(solar20.index, solarGen, color='yellow', label="solar availability (%)", alpha=0.1)
plt.ylim(0, 100)
plt.xlim(solar20.index[0], solar20.index[-1])

norm = matplotlib.colors.Normalize(vmin=min(carbon),vmax=max(carbon))
sm = plt.cm.ScalarMappable(cmap=plt.get_cmap("coolwarm"), norm=norm)
sm.set_array([])
plt.colorbar(sm, ticks=np.arange(np.floor(min(carbon)), np.ceil(max(carbon)), 20), boundaries=np.arange(min(carbon)-10,max(carbon)+10,1))
plt.tight_layout()
# put the legend at the bottom with two columns
plt.legend(loc='lower center', ncol=2, bbox_to_anchor=(0.5, -0.1))
plt.ylabel("solar availability (%)")
plt.title("2020 CAISO Carbon Intensity vs. Solar Offsets from 20kW DC system (continuous 19kW load)")

plt.show()

# %%
# for each hour, plot a bar graph, where the top half is the percentage of energy not met by solar, and the bottom half is the percentage of energy met by solar
# the color of the top half is based on the carbon intensity
# the color of the bottom half is yellow
import matplotlib

# just 2021 values
solar21 = gen[gen.index.year == 2021]
cf21 = cf[cf.index.year == 2021]

# raw carbon values
carbon = np.array(cf21['carbon_intensity'].to_list())

my_cmap = plt.get_cmap("coolwarm")
rescale = lambda y: (y - np.min(y)) / (np.max(y) - np.min(y))

normalized = [100 for _ in carbon]

# raw solar values
solar = np.array(solar21['Solar Generation (kWh)'].to_list())
# normalized for a 19kW load
solarGen = (solar / 19) * 100

plt.figure(figsize=(18,4), dpi=200)
plt.bar(solar21.index, normalized, color=my_cmap(rescale(carbon)), label="grid electricity")
plt.bar(solar21.index, solarGen, color='yellow', label="solar availability (%)", alpha=0.1)
plt.ylim(0, 100)
plt.xlim(solar21.index[0], solar21.index[-1])

norm = matplotlib.colors.Normalize(vmin=min(carbon),vmax=max(carbon))
sm = plt.cm.ScalarMappable(cmap=plt.get_cmap("coolwarm"), norm=norm)
sm.set_array([])
plt.colorbar(sm, ticks=np.arange(np.floor(min(carbon)), np.ceil(max(carbon)), 20), boundaries=np.arange(min(carbon)-10,max(carbon)+10,1))
plt.tight_layout()
# put the legend at the bottom with two columns
plt.legend(loc='lower center', ncol=2, bbox_to_anchor=(0.5, -0.1))
plt.ylabel("solar availability (%)")
plt.title("2021 CAISO Carbon Intensity vs. Solar Offsets from 20kW DC system (continuous 19kW load)")

plt.show()

# %%
import pyximport; pyximport.install()
import functions as f
from scipy.special import lambertw
import math

U = 338.74
L = 18.18
beta = 20

# plot the threshold function on the interval (0,1)
alpha = 1 / (1 - (2*beta/U) + lambertw( ( ( (2*beta/U) + (L/U) - 1 ) * math.exp(2*beta/U) ) / math.e ) )
print(alpha)

function = []
for x in np.linspace(0,1,100):
    function.append(f.thresholdFunc(x, U, L, beta, alpha))

plt.plot(np.linspace(0,1,100), function)
# Out:
# (4.724163527875144+0j)
# <ipython-input-3-0fe0d390217d>:16: ComplexWarning: Casting complex values to real discards the imaginary part
#   function.append(f.thresholdFunc(x, U, L, beta, alpha))

# %%
from scipy import integrate

print(integrate.quad(f.thresholdFunc, 0.0, 0.05, args=(U,L,beta,alpha))[0])

print(87.24*0.1 + 20*0.1)
# Out:
# 4.524899613851118
# 10.724
# /Users/adam/miniforge3/lib/python3.8/site-packages/scipy/integrate/quadpack.py:463: ComplexWarning: Casting complex values to real discards the imaginary part
#   return _quadpack._qagse(func,a,b,args,full_output,epsabs,epsrel,limit)

# %%
U = 338.74
L = 18.18
beta = 20

# plot the threshold function on the interval (0,1)
alpha = 1 / (1 + lambertw( ( (L/U) - 1 ) / math.e ) )
print(alpha)

function = []
for x in np.linspace(0,1,1000):
    function.append(f.owtThreshold(U, L, alpha, x))

plt.plot(np.linspace(0,1,100), function)
# Out:
# (3.373329702330749+0j)
# <ipython-input-86-3bc6e39a553e>:11: ComplexWarning: Casting complex values to real discards the imaginary part
#   function.append(f.owtThreshold(U, L, alpha, x))

# %%
print(math.sqrt(U*L))
# Out:
# 78.47479340527123
